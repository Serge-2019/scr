# %%
import pandas as pd

df = pd.read_csv('result.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0                              Наименование вакансии  \
# 0            0  Управляющий / Директор / Менеджер магазина DES...
# 1            1                     Менеджер по работе с клиентами
# 2            2             Менеджер по продажам / Account Manager
# 3            3                    Менеджер по экспортным продажам
# 4            4  Менеджер по закупкам (с опытом работы на фарма...
# 5            5           Менеджер в отдел аренды квартир и комнат
# 6            6              Менеджер по коммерческой недвижимости
# 7            7               Менеджер по продажам бизнес-клиентам
# 8            8                  Менеджер по продажам оборудования
# 9            9                               Менеджер по продажам
# 10          10  Менеджер по работе с недвижимостью / Агент (м....
# 11          11                               Менеджер по продажам
# 12          12  Менеджер по продажам / Агент / Риелтор (новый ...
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0   Зарплата MIN   Зарплата MAX
# count   240.00000     218.000000     124.000000
# mean    119.50000   65541.284404  151290.322581
# std      69.42622   19082.784535   65772.059478
# min       0.00000   30000.000000   45000.000000
# 25%      59.75000   50000.000000  120000.000000
# 50%     119.50000   60000.000000  150000.000000
# 75%     179.25000   80000.000000  180000.000000
# max     239.00000  113000.000000  500000.000000
