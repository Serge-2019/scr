# %%
import pandas as pd

df = pd.read_json('result.json')

# %%
df.head(20)
# Out:
#                                  Наименование вакансии  Зарплата MIN  \
# 0    Администратор торгового зала в сеть супермарке...       39000.0
# 1                         Администратор в стоматологию       30000.0
# 10           Администратор / Секретарь / Офис-менеджер       30000.0
# 100  Администратор торгового зала в сеть супермарке...       39000.0
# 101                       Администратор в стоматологию       30000.0
# 102                       Главный администратор театра       40000.0
# 103           Администратор по сопровождению пациентов       40000.0
# 104  Администратор магазина / Старший продавец (ТРЦ...           NaN
# 105                      Администратор магазина (ночь)       43000.0
# 106                            Администратор ресторана       30000.0
# 107                                      Администратор       24500.0
# 108                  Администратор медицинского центра       50000.0
# 109                           Администратор СПА-салона       30000.0
# ...

# %%
df.describe()
# Out:
#         Зарплата MIN   Зарплата MAX
# count     142.000000      74.000000
# mean    43322.112676   67801.891892
# std     14359.023522   31828.540788
# min     24500.000000   35000.000000
# 25%     30000.000000   43500.000000
# 50%     40000.000000   55000.000000
# 75%     50000.000000   85000.000000
# max    100000.000000  150000.000000
